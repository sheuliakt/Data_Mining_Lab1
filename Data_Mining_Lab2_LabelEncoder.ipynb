# %%
import pandas as pd

# %%
tem1=pd.read_csv("temfile.csv")

# %%
tem1.head()
# Out:
#        City country_id      Country Latitude Longitude
# 0  Auckland        NEW  New Zealand   36.17S   175.03E
# 1  Auckland        NEW  New Zealand   36.17S   175.03E
# 2  Auckland        NEW  New Zealand   36.17S   175.03E
# 3  Auckland        NEW  New Zealand   36.17S   175.03E
# 4  Auckland        NEW  New Zealand   36.17S   175.03E

# %%
tem1.tail()
# Out:
#           City country_id Country Latitude Longitude
# 48465  Wroclaw        POL  Poland   50.63N    16.48E
# 48466  Wroclaw        POL  Poland   50.63N    16.48E
# 48467  Wroclaw        POL  Poland   50.63N    16.48E
# 48468  Wroclaw        POL  Poland   50.63N    16.48E
# 48469  Wroclaw        POL  Poland   50.63N    16.48E

# %%
tem1.head(20)
# Out:
#         City country_id      Country Latitude Longitude
# 0   Auckland        NEW  New Zealand   36.17S   175.03E
# 1   Auckland        NEW  New Zealand   36.17S   175.03E
# 2   Auckland        NEW  New Zealand   36.17S   175.03E
# 3   Auckland        NEW  New Zealand   36.17S   175.03E
# 4   Auckland        NEW  New Zealand   36.17S   175.03E
# 5   Auckland        NEW  New Zealand   36.17S   175.03E
# 6   Auckland        NEW  New Zealand   36.17S   175.03E
# 7   Auckland        NEW  New Zealand   36.17S   175.03E
# 8   Auckland        NEW  New Zealand   36.17S   175.03E
# 9   Auckland        NEW  New Zealand   36.17S   175.03E
# 10  Auckland        NEW  New Zealand   36.17S   175.03E
# 11  Auckland        NEW  New Zealand   36.17S   175.03E
# 12  Auckland        NEW  New Zealand   36.17S   175.03E
# 13  Auckland        NEW  New Zealand   36.17S   175.03E
# 14  Auckland        NEW  New Zealand   36.17S   175.03E
# 15  Auckland        NEW  New Zealand   36.17S   175.03E
# ...

# %%
tem1.sample()
# Out:
#         City country_id  Country Latitude Longitude
# 28043  Odesa        UKR  Ukraine   45.81N    31.15E

# %%
print(tem1)
# Out:
#            City country_id      Country Latitude Longitude
# 0      Auckland        NEW  New Zealand   36.17S   175.03E
# 1      Auckland        NEW  New Zealand   36.17S   175.03E
# 2      Auckland        NEW  New Zealand   36.17S   175.03E
# 3      Auckland        NEW  New Zealand   36.17S   175.03E
# 4      Auckland        NEW  New Zealand   36.17S   175.03E
# ...         ...        ...          ...      ...       ...
# 48465   Wroclaw        POL       Poland   50.63N    16.48E
# 48466   Wroclaw        POL       Poland   50.63N    16.48E
# 48467   Wroclaw        POL       Poland   50.63N    16.48E
# 48468   Wroclaw        POL       Poland   50.63N    16.48E
# 48469   Wroclaw        POL       Poland   50.63N    16.48E
#
# [48470 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder=LabelEncoder()

# %%
tem1['cityencoding']=labelencoder.fit_transform(tem1['City'].astype(str))

# %%
print(tem1)
# Out:
#            City country_id      Country Latitude Longitude  cityencoding
# 0      Auckland        NEW  New Zealand   36.17S   175.03E             0
# 1      Auckland        NEW  New Zealand   36.17S   175.03E             0
# 2      Auckland        NEW  New Zealand   36.17S   175.03E             0
# 3      Auckland        NEW  New Zealand   36.17S   175.03E             0
# 4      Auckland        NEW  New Zealand   36.17S   175.03E             0
# ...         ...        ...          ...      ...       ...           ...
# 48465   Wroclaw        POL       Poland   50.63N    16.48E            17
# 48466   Wroclaw        POL       Poland   50.63N    16.48E            17
# 48467   Wroclaw        POL       Poland   50.63N    16.48E            17
# 48468   Wroclaw        POL       Poland   50.63N    16.48E            17
# 48469   Wroclaw        POL       Poland   50.63N    16.48E            17
#
# [48470 rows x 6 columns]

# %%
tem1.sample()
# Out:
#         City country_id Country Latitude Longitude  cityencoding
# 35790  Tokyo        JAP   Japan   36.17N   139.23E            13

# %%
tem1.head(200)
# Out:
#          City country_id      Country Latitude Longitude  cityencoding
# 0    Auckland        NEW  New Zealand   36.17S   175.03E             0
# 1    Auckland        NEW  New Zealand   36.17S   175.03E             0
# 2    Auckland        NEW  New Zealand   36.17S   175.03E             0
# 3    Auckland        NEW  New Zealand   36.17S   175.03E             0
# 4    Auckland        NEW  New Zealand   36.17S   175.03E             0
# ..        ...        ...          ...      ...       ...           ...
# 195  Auckland        NEW  New Zealand   36.17S   175.03E             0
# 196  Auckland        NEW  New Zealand   36.17S   175.03E             0
# 197  Auckland        NEW  New Zealand   36.17S   175.03E             0
# 198  Auckland        NEW  New Zealand   36.17S   175.03E             0
# 199  Auckland        NEW  New Zealand   36.17S   175.03E             0
#
# [200 rows x 6 columns]
