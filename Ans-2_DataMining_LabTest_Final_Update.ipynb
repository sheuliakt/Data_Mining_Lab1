# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("labtest 1.csv")

# %%
df.head(10)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0  101            6.3           3.3            6.0           2.5
# 1  102            5.8           2.7            5.1           0.0
# 2  103            7.1           3.0            5.9           2.1
# 3  104            6.3           2.9            5.6           1.8
# 4  105            6.5           3.0            5.8           2.2
# 5  106            7.6           3.0            6.6           2.1
# 6  107            4.9           2.5            4.5           1.7
# 7  108            7.3           2.9            6.3           1.8
# 8  109            6.7           2.5            5.8           0.0
# 9  110            7.2           3.6            6.1           2.5
#
#           Species
# 0  Iris-virginica
# 1  Iris-virginica
# 2  Iris-virginica
# 3  Iris-virginica
# 4  Iris-virginica
# 5  Iris-virginica
# 6  Iris-virginica
# 7  Iris-virginica
# 8  Iris-virginica
# 9  Iris-virginica

# %%
df.tail(10)
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 40  141            6.7           3.1            5.6           2.4
# 41  142            6.9           3.1            5.1           2.3
# 42  143            5.8           2.7            5.1           1.9
# 43  144            6.8           3.2            5.9           2.3
# 44  145            6.7           3.3            5.7           2.5
# 45  146            6.7           3.0            5.2           2.3
# 46  147            6.3           2.5            5.0           1.9
# 47  148            6.5           3.0            5.2           2.0
# 48  149            6.2           3.4            5.4           2.3
# 49  150            5.9           3.0            5.1           1.8
#
#            Species
# 40  Iris-virginica
# 41  Iris-virginica
# 42  Iris-virginica
# 43  Iris-virginica
# 44  Iris-virginica
# 45  Iris-virginica
# 46  Iris-virginica
# 47  Iris-virginica
# 48  Iris-virginica
# 49  Iris-virginica

# %%
print(df.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df['PetalWidthCm']=df['PetalWidthCm'].replace(0, np.nan)

# %%
print(df)
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0   101            6.3           3.3            6.0           2.5
# 1   102            5.8           2.7            5.1           NaN
# 2   103            7.1           3.0            5.9           2.1
# 3   104            6.3           2.9            5.6           1.8
# 4   105            6.5           3.0            5.8           2.2
# 5   106            7.6           3.0            6.6           2.1
# 6   107            4.9           2.5            4.5           1.7
# 7   108            7.3           2.9            6.3           1.8
# 8   109            6.7           2.5            5.8           NaN
# 9   110            7.2           3.6            6.1           2.5
# 10  111            6.5           3.2            5.1           2.0
# 11  112            6.4           2.7            5.3           NaN
# 12  113            6.8           3.0            5.5           2.1
# ...

# %%
df2=df[df["PetalWidthCm"].notnull()]

# %%
print(df2)
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0   101            6.3           3.3            6.0           2.5
# 2   103            7.1           3.0            5.9           2.1
# 3   104            6.3           2.9            5.6           1.8
# 4   105            6.5           3.0            5.8           2.2
# 5   106            7.6           3.0            6.6           2.1
# 6   107            4.9           2.5            4.5           1.7
# 7   108            7.3           2.9            6.3           1.8
# 9   110            7.2           3.6            6.1           2.5
# 10  111            6.5           3.2            5.1           2.0
# 12  113            6.8           3.0            5.5           2.1
# 13  114            5.7           2.5            5.0           2.0
# 14  115            5.8           2.8            5.1           2.4
# 16  117            6.5           3.0            5.5           1.8
# ...
