# %%
import pandas as pd

# %%
tem1=pd.read_csv("test_scores.csv")

# %%
tem1.head()
# Out:
#   school school_setting school_type classroom teaching_method  n_student  \
# 0  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 1  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 2  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 3  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 4  ANKYI          Urban  Non-public       6OL        Standard       20.0
#
#   student_id  gender             lunch  pretest  posttest
# 0      2FHT3  Female  Does not qualify     62.0      72.0
# 1      3JIVH  Female  Does not qualify     66.0      79.0
# 2      3XOWE    Male  Does not qualify     64.0      76.0
# 3      556O0  Female  Does not qualify     61.0      77.0
# 4      74LOE    Male  Does not qualify     64.0      76.0

# %%
tem1.tail()
# Out:
#      school school_setting school_type classroom teaching_method  n_student  \
# 2128  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2129  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2130  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2131  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2132  ZOWMK          Urban      Public       ZBH        Standard       30.0
#
#      student_id  gender                             lunch  pretest  posttest
# 2128      T8LSK  Female                  Does not qualify     39.0      55.0
# 2129      VNP26  Female  Qualifies for reduced/free lunch     38.0      46.0
# 2130      YDR1Z  Female  Qualifies for reduced/free lunch     45.0      51.0
# 2131      YUEIH    Male  Qualifies for reduced/free lunch     46.0      53.0
# 2132      ZVCQ8    Male  Qualifies for reduced/free lunch     41.0      48.0

# %%
tem1.head(20)
# Out:
#    school school_setting school_type classroom teaching_method  n_student  \
# 0   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 1   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 2   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 3   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 4   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 5   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 6   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 7   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 8   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 9   ANKYI          Urban  Non-public       6OL        Standard       20.0
# 10  ANKYI          Urban  Non-public       6OL        Standard       20.0
# 11  ANKYI          Urban  Non-public       6OL        Standard       20.0
# ...

# %%
tem1.sample()
# Out:
#      school school_setting school_type classroom teaching_method  n_student  \
# 1863  VVTVA          Urban      Public       A93    Experimental       30.0
#
#      student_id  gender                             lunch  pretest  posttest
# 1863      0JIY9  Female  Qualifies for reduced/free lunch     30.0      49.0

# %%
print(tem1)
# Out:
#      school school_setting school_type classroom teaching_method  n_student  \
# 0     ANKYI          Urban  Non-public       6OL        Standard       20.0
# 1     ANKYI          Urban  Non-public       6OL        Standard       20.0
# 2     ANKYI          Urban  Non-public       6OL        Standard       20.0
# 3     ANKYI          Urban  Non-public       6OL        Standard       20.0
# 4     ANKYI          Urban  Non-public       6OL        Standard       20.0
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2129  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2130  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2131  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2132  ZOWMK          Urban      Public       ZBH        Standard       30.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder=LabelEncoder()

# %%
tem1['schoolencoding']=labelencoder.fit_transform(tem1['school'].astype(str))

# %%
print(tem1)
# Out:
#      school school_setting school_type classroom teaching_method  n_student  \
# 0     ANKYI          Urban  Non-public       6OL        Standard       20.0
# 1     ANKYI          Urban  Non-public       6OL        Standard       20.0
# 2     ANKYI          Urban  Non-public       6OL        Standard       20.0
# 3     ANKYI          Urban  Non-public       6OL        Standard       20.0
# 4     ANKYI          Urban  Non-public       6OL        Standard       20.0
# ...     ...            ...         ...       ...             ...        ...
# 2128  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2129  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2130  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2131  ZOWMK          Urban      Public       ZBH        Standard       30.0
# 2132  ZOWMK          Urban      Public       ZBH        Standard       30.0
#
# ...

# %%
tem1.sample()
# Out:
#      school school_setting school_type classroom teaching_method  n_student  \
# 1418  UAGPU       Suburban      Public       62L        Standard       23.0
#
#      student_id gender             lunch  pretest  posttest  schoolencoding
# 1418      P5X30   Male  Does not qualify     62.0      72.0              15

# %%
tem1.head(200)
# Out:
#     school school_setting school_type classroom teaching_method  n_student  \
# 0    ANKYI          Urban  Non-public       6OL        Standard       20.0
# 1    ANKYI          Urban  Non-public       6OL        Standard       20.0
# 2    ANKYI          Urban  Non-public       6OL        Standard       20.0
# 3    ANKYI          Urban  Non-public       6OL        Standard       20.0
# 4    ANKYI          Urban  Non-public       6OL        Standard       20.0
# ..     ...            ...         ...       ...             ...        ...
# 195  CIMBB          Urban  Non-public       HUJ    Experimental       17.0
# 196  CIMBB          Urban  Non-public       HUJ    Experimental       17.0
# 197  CIMBB          Urban  Non-public       HUJ    Experimental       17.0
# 198  CIMBB          Urban  Non-public       HUJ    Experimental       17.0
# 199  CIMBB          Urban  Non-public       HUJ    Experimental       17.0
#
# ...
